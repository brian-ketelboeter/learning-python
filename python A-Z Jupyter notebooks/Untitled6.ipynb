# %%
import numpy as np

# %%
from numpy.random import randn

# %%
for k in range(1,10000):
    total = 0
    for n in range(k):
        x = randn()
        total = total + x
    avg = total / k
    print(k,avg)
# Out:
# 1 0.7911057197346127
# 2 0.09895191883291388
# 3 0.14687409406894572
# 4 0.7116190615601227
# 5 0.7057314797577625
# 6 0.09146606753248837
# 7 -0.29411966778690274
# 8 0.23500579217936643
# 9 -0.38537680444819733
# 10 0.17050457585492101
# 11 -0.1294480293381567
# 12 -0.34561428183104725
# 13 0.5555426185462659
# 14 -0.4906417615999894
# 15 0.08024371863600045
# 16 0.14658274602924956
# 17 -0.19658960707345388
# 18 -0.3049930587144468
# 19 -0.0569696371715232
# 20 -0.06369784898543795
# 21 -0.16987476953102848
# 22 -0.04554414498827011
# 23 -0.007823644747969087
# 24 -0.17581530415734595
# 25 -0.05335098713235486
# 26 -0.1507672649141867
# 27 0.2818637448414985
# 28 -0.09726881969857182
# 29 -0.12964288696722495
# 30 -0.14733566704576884
# 31 0.1458311044044336
# 32 -0.12382278833689461
# 33 0.012982179789828857
# 34 -0.11354109160687084
# 35 -0.08487455495299734
# 36 -0.025456835069792228
# 37 0.09205038743162183
# 38 -0.3350380455796917
# 39 -0.23338335888133166
# ...
